# %%
## whisper from source

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /private/var/folders/xm/82jt8mcn7kn_6qqcn6zfcjj00000gn/T/pip-req-build-zuywweij
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /private/var/folders/xm/82jt8mcn7kn_6qqcn6zfcjj00000gn/T/pip-req-build-zuywweij
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached numba-0.59.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.7 kB)
# ...
#   Using cached numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (61 kB)
# ...
#   Using cached torch-2.3.1-cp39-none-macosx_11_0_arm64.whl.metadata (26 kB)
# ...
#   Using cached llvmlite-0.42.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.8 kB)
# ...
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# ...

# %%
# !cd data
# !whisper data/processed_earning_call_morepen_10.ogg
# Out:
# /Users/anubhavtomar/2023_projects/chatgpt/.venv/lib/python3.9/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:06.960]  Ladies and gentlemen, good day and welcome to Morphen Labor Tree's limited Q4FI24 conference
# [00:06.960 --> 00:11.280]  call hosted by Motilal Oswal Financial Services Limited.
# [00:11.280 --> 00:15.640]  As a reminder, all participant lines will be in the listen-only mode and there will be
# [00:15.640 --> 00:20.080]  an opportunity for you to ask questions after the presentation concludes.
# [00:20.080 --> 00:24.240]  Should you need assistance during the conference call, please signal an operator by pressing
# [00:24.240 --> 00:27.200]  star 10-0 on your touchstone phone.
# ...
